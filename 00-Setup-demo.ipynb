# %% [markdown]
# # 1) Install Chatbot Widget

# %%
# %%capture
# # '%%capture' suppresses the display of installation steps of the following packages
# !pip install "git+https://github.com/martinhillebrand/chatbot-widget.git"

# %%
# %%capture
# # '%%capture' suppresses the display of installation steps of the following packages
# !pip install teradataml-plus plotly

# %%
try:
    import chatbot_widget
    print("chatbot_widget installed")
except:
    print("chatbot_widget could not be loaded, please restart the kernel")
# Out:
# chatbot_widget could not be loaded, please restart the kernel

# %% [markdown]
# # 2) Optional: Get the teradata-mcp-server (Community Edition) Code

# %%
# !git clone  https://github.com/Teradata/teradata-mcp-server.git
# Out:
# Cloning into 'teradata-mcp-server'...
# remote: Enumerating objects: 3752, done.
# remote: Counting objects: 100% (660/660), done.
# remote: Compressing objects: 100% (151/151), done.
# remote: Total 3752 (delta 551), reused 518 (delta 508), pack-reused 3092 (from 2)
# Receiving objects: 100% (3752/3752), 80.90 MiB | 32.78 MiB/s, done.
# Resolving deltas: 100% (2235/2235), done.

# %%
# !ls
# Out:
# 00-Setup-demo.ipynb	      example_chat.png	      tdmcpcommunity.py
# 01-explore-MCP-Servers.ipynb  README.md		      teradata-mcp-server
# 02-chat-with-MCP.ipynb	      sample_data_jaffleshop

# %%
import tomllib,shlex

with open("teradata-mcp-server/pyproject.toml", "rb") as f:
    deps = tomllib.load(f)["project"]["dependencies"]
deps_str = " ".join(shlex.quote(d) for d in deps)

print(deps_str)
# Out:
# 'pydantic>=2.8.0,<3.0.0' 'fastmcp>=2.12.0,<3.0.0' 'mcp[cli]>=1.0.0,<2.0.0' 'teradatasqlalchemy>=20.0.0.0' 'python-dotenv>=1.0.0' 'PyYAML>=6.0.0' 'sqlalchemy>=2.0.0,<3.0.0'

# %%
# %%capture
# # '%%capture' suppresses the display of installation steps of the following packages
# !pip install -U {deps_str}

# %% [markdown]
# **FYI: We can start the MCP server later through the wrapper script tdmcpcommunity.py**
#
# **Restart the kernel of this notebook now!**

# %% [markdown]
# # 3 Load some dummy data to the demo_user database

# %%
host = 'host.docker.internal'
user = 'demo_user'

# %%
import getpass
db_pw = getpass.getpass("Enter DB Password here")
# Out:
# Enter DB Password here ················

# %%
import tdmlplus
import teradataml as tdml
import os
import pandas as pd

# %%
tdml.create_context(host, user, db_pw)
# Out:
# Engine(teradatasql://demo_user:***@host.docker.internal)

# %%
all_csvs = os.listdir("sample_data_jaffleshop/")
for f in all_csvs:
    if f.endswith(".csv"):
        table_name = f.split(".csv")[0]
        df = pd.read_csv("sample_data_jaffleshop/"+f)
        tdml.copy_to_sql(df, table_name, if_exists="replace")
        print(table_name, " uploaded")
# Out:
# dim_payment_method  uploaded
# customer_lifetime_value  uploaded
# dim_customers  uploaded
# sim_payments  uploaded
# key_customer  uploaded
# raw_customers  uploaded
# stg_payments  uploaded
# stg_orders  uploaded
# sim_customers  uploaded
# sim_orders  uploaded
# fct_orders  uploaded
# lim_payments  uploaded
# lim_orders  uploaded
# lim_customers  uploaded
# stg_customers  uploaded
# customer  uploaded
# order_payments  uploaded
# raw_orders  uploaded
# raw_payments  uploaded

# %%
tdml.widgets.tab_dfs(table_names = [f.split(".csv")[0] for f in all_csvs] )
# Out:
#     <style>
#         .tab-container-40bf9ab6937f4ba3b5d06b8f6c0503ec {
#             border-bottom: 2px solid #ddd;
#             display: flex;
#         }
#         .tab-label-40bf9ab6937f4ba3b5d06b8f6c0503ec {
#             padding: 10px 15px;
#             cursor: pointer;
#             border: 1px solid #ddd;
#             border-bottom: none;
#             background: #f1f1f1;
#             margin-right: 5px;
#         }
#         .tab-label-40bf9ab6937f4ba3b5d06b8f6c0503ec.active {
#             background: white;
#             border-top: 2px solid #007bff;
#             font-weight: bold;
#         }
#         .tab-content-40bf9ab6937f4ba3b5d06b8f6c0503ec {
#             display: none;
#             padding: 15px;
#             border: 1px solid #ddd;
#             text-align: left;
#         }
#         .tab-content-40bf9ab6937f4ba3b5d06b8f6c0503ec.active {
#             display: block;
#         }
#     </style>
#
#     <div class="tab-container-40bf9ab6937f4ba3b5d06b8f6c0503ec">
#     <div class="tab-label-40bf9ab6937f4ba3b5d06b8f6c0503ec active" data-tab="d3588fe4b46e470f928930e009aed99a">dim_payment_method</div><div class="tab-label-40bf9ab6937f4ba3b5d06b8f6c0503ec " data-tab="33790493d32a4bb89551b1aaf0aebb43">customer_lifetime_value</div><div class="tab-label-40bf9ab6937f4ba3b5d06b8f6c0503ec " data-tab="3538dc1409404d628169733295f9f959">dim_customers</div><div class="tab-label-40bf9ab6937f4ba3b5d06b8f6c0503ec " data-tab="54e39423277b4466b8b2f5e9c6fe6102">sim_payments</div><div class="tab-label-40bf9ab6937f4ba3b5d06b8f6c0503ec " data-tab="176956299b424a42a611a073f1982c70">key_customer</div><div class="tab-label-40bf9ab6937f4ba3b5d06b8f6c0503ec " data-tab="40bebd334ad54b02ba5d4b6cc95e0ef1">raw_customers</div><div class="tab-label-40bf9ab6937f4ba3b5d06b8f6c0503ec " data-tab="0c20abf8153543db87c38fa6c07bde4c">stg_payments</div><div class="tab-label-40bf9ab6937f4ba3b5d06b8f6c0503ec " data-tab="8b0efdd4c6a4444da24b38df1c4901e2">stg_orders</div><div class="tab-label-40bf9ab6937f4ba3b5d06b8f6c0503ec " data-tab="9643bae4dbce410aabbe279a3fa41e96">sim_customers</div><div class="tab-label-40bf9ab6937f4ba3b5d06b8f6c0503ec " data-tab="ee6c4120e32c42bea87c3f8b4d77d75a">sim_orders</div><div class="tab-label-40bf9ab6937f4ba3b5d06b8f6c0503ec " data-tab="900e36b6e9d34f5e9b8337796741e6f1">fct_orders</div><div class="tab-label-40bf9ab6937f4ba3b5d06b8f6c0503ec " data-tab="2f680c81d8784f9dbbaad7cff788f77a">lim_payments</div><div class="tab-label-40bf9ab6937f4ba3b5d06b8f6c0503ec " data-tab="2003eac31be7431a8103433f4feac503">lim_orders</div><div class="tab-label-40bf9ab6937f4ba3b5d06b8f6c0503ec " data-tab="1730940d53774462bd623662c6e84a6b">lim_customers</div><div class="tab-label-40bf9ab6937f4ba3b5d06b8f6c0503ec " data-tab="b3fe26bb60db4974a5f177b7e2b7ac11">stg_customers</div><div class="tab-label-40bf9ab6937f4ba3b5d06b8f6c0503ec " data-tab="43e2011e73e345ed912e3f6783052f1c">customer</div><div class="tab-label-40bf9ab6937f4ba3b5d06b8f6c0503ec " data-tab="a5721a2b04694aff888c156e52ce9bfa">order_payments</div><div class="tab-label-40bf9ab6937f4ba3b5d06b8f6c0503ec " data-tab="d43a1fe0a5284debbba663bb863cf9c6">raw_orders</div><div class="tab-label-40bf9ab6937f4ba3b5d06b8f6c0503ec " data-tab="bfb6d0de55dd4f4c989ea33aeab13c4e">raw_payments</div></div><div class="tab-content-40bf9ab6937f4ba3b5d06b8f6c0503ec active" id="tab-d3588fe4b46e470f928930e009aed99a"><style type="text/css">
# 	table { border:ridge 5px}
# 	table td {border:inset 1px;}
# 	table tr#HeaderRow {background-color:grey; color:white;}
# 	</style>
# <html><table style="min-width:1000px;">
# 	<tr id="HeaderRow">
# <th>payment_method</th><th>total_amount</th><th>frequency_count</th>
# </tr>
# 	<tr>
# 		<td>bank_transfer</td>
# 		<td>411</td>
# 		<td>33</td>
# 	</tr>
# 	<tr>
# 		<td>gift_card</td>
# 		<td>205</td>
# 		<td>12</td>
# 	</tr>
# 	<tr>
# 		<td>credit_card</td>
# 		<td>871</td>
# 		<td>55</td>
# 	</tr>
# 	<tr>
# 		<td>coupon</td>
# 		<td>185</td>
# 		<td>13</td>
# 	</tr>
# </table></html></div><div class="tab-content-40bf9ab6937f4ba3b5d06b8f6c0503ec " id="tab-33790493d32a4bb89551b1aaf0aebb43"><style type="text/css">
# 	table { border:ridge 5px}
# 	table td {border:inset 1px;}
# 	table tr#HeaderRow {background-color:grey; color:white;}
# 	</style>
# <html><table style="min-width:1000px;">
# 	<tr id="HeaderRow">
# <th>customer_key</th><th>total_amount_usd</th><th>valid_period</th>
# </tr>
# 	<tr>
# 		<td>2</td>
# 		<td>15</td>
# 		<td>2018-01-23,9999-12-31</td>
# 	</tr>
# 	<tr>
# 		<td>6</td>
# 		<td>4</td>
# 		<td>2018-03-03,9999-12-31</td>
# 	</tr>
# 	<tr>
# 		<td>15</td>
# 		<td>25</td>
# 		<td>2018-01-05,2018-02-20</td>
# 	</tr>
# 	<tr>
# 		<td>19</td>
# 		<td>28</td>
# 		<td>2018-03-02,2018-03-14</td>
# 	</tr>
# 	<tr>
# 		<td>9</td>
# 		<td>8</td>
# 		<td>2018-02-11,2018-03-08</td>
# 	</tr>
# 	<tr>
# 		<td>15</td>
# 		<td>47</td>
# 		<td>2018-02-20,9999-12-31</td>
# 	</tr>
# 	<tr>
# 		<td>3</td>
# 		<td>39</td>
# 		<td>2018-03-11,9999-12-31</td>
# 	</tr>
# 	<tr>
# 		<td>3</td>
# 		<td>23</td>
# 		<td>2018-01-12,2018-03-11</td>
# 	</tr>
# 	<tr>
# 		<td>8</td>
# 		<td>12</td>
# 		<td>2018-02-02,9999-12-31</td>
# 	</tr>
# 	<tr>
# 		<td>1</td>
# 		<td>1</td>
# 		<td>2018-01-15,9999-12-31</td>
# 	</tr>
# </table></html></div><div class="tab-content-40bf9ab6937f4ba3b5d06b8f6c0503ec " id="tab-3538dc1409404d628169733295f9f959"><style type="text/css">
# 	table { border:ridge 5px}
# 	table td {border:inset 1px;}
# 	table tr#HeaderRow {background-color:grey; color:white;}
# 	</style>
# <html><table style="min-width:1000px;">
# 	<tr id="HeaderRow">
# <th>customer_key</th><th>first_order</th><th>most_recent_order</th><th>number_of_orders</th><th>customer_lifetime_value</th>
# </tr>
# 	<tr>
# 		<td>40</td>
# 		<td>None</td>
# 		<td>None</td>
# 		<td>None</td>
# 		<td>None</td>
# 	</tr>
# 	<tr>
# 		<td>38</td>
# 		<td>None</td>
# 		<td>None</td>
# 		<td>None</td>
# 		<td>None</td>
# 	</tr>
# 	<tr>
# 		<td>34</td>
# 		<td>None</td>
# 		<td>None</td>
# 		<td>None</td>
# 		<td>None</td>
# 	</tr>
# 	<tr>
# 		<td>80</td>
# 		<td>2018-01-31</td>
# 		<td>2018-03-05</td>
# 		<td>2.0</td>
# 		<td>26.0</td>
# 	</tr>
# 	<tr>
# 		<td>78</td>
# 		<td>2018-02-08</td>
# 		<td>2018-02-08</td>
# 		<td>1.0</td>
# 		<td>29.0</td>
# 	</tr>
# 	<tr>
# 		<td>13</td>
# 		<td>2018-02-21</td>
# 		<td>2018-04-04</td>
# 		<td>2.0</td>
# 		<td>27.0</td>
# 	</tr>
# 	<tr>
# 		<td>59</td>
# 		<td>None</td>
# 		<td>None</td>
# 		<td>None</td>
# 		<td>None</td>
# 	</tr>
# 	<tr>
# 		<td>19</td>
# 		<td>2018-03-02</td>
# 		<td>2018-03-14</td>
# 		<td>2.0</td>
# 		<td>57.0</td>
# 	</tr>
# 	<tr>
# 		<td>17</td>
# 		<td>None</td>
# 		<td>None</td>
# 		<td>None</td>
# 		<td>None</td>
# 	</tr>
# 	<tr>
# 		<td>61</td>
# 		<td>2018-03-23</td>
# 		<td>2018-03-23</td>
# 		<td>1.0</td>
# 		<td>27.0</td>
# 	</tr>
# </table></html></div><div class="tab-content-40bf9ab6937f4ba3b5d06b8f6c0503ec " id="tab-54e39423277b4466b8b2f5e9c6fe6102"><style type="text/css">
# 	table { border:ridge 5px}
# 	table td {border:inset 1px;}
# 	table tr#HeaderRow {background-color:grey; color:white;}
# 	</style>
# <html><table style="min-width:1000px;">
# 	<tr id="HeaderRow">
# <th>id</th><th>order_id</th><th>payment_method</th><th>amount</th><th>last_update_ts</th>
# </tr>
# 	<tr>
# 		<td>3</td>
# 		<td>3</td>
# 		<td>coupon</td>
# 		<td>100</td>
# 		<td>2025-09-02 10:15:32.045147</td>
# 	</tr>
# 	<tr>
# 		<td>5</td>
# 		<td>5</td>
# 		<td>bank_transfer</td>
# 		<td>1700</td>
# 		<td>2025-09-02 10:15:32.045147</td>
# 	</tr>
# 	<tr>
# 		<td>6</td>
# 		<td>6</td>
# 		<td>credit_card</td>
# 		<td>600</td>
# 		<td>2025-09-02 10:15:32.045147</td>
# 	</tr>
# 	<tr>
# 		<td>7</td>
# 		<td>7</td>
# 		<td>credit_card</td>
# 		<td>1600</td>
# 		<td>2025-09-02 10:15:32.045147</td>
# 	</tr>
# 	<tr>
# 		<td>9</td>
# 		<td>9</td>
# 		<td>gift_card</td>
# 		<td>2300</td>
# 		<td>2025-09-02 10:15:32.045147</td>
# 	</tr>
# 	<tr>
# 		<td>10</td>
# 		<td>9</td>
# 		<td>bank_transfer</td>
# 		<td>0</td>
# 		<td>2025-09-02 10:15:32.045147</td>
# 	</tr>
# 	<tr>
# 		<td>8</td>
# 		<td>8</td>
# 		<td>credit_card</td>
# 		<td>2300</td>
# 		<td>2025-09-02 10:15:32.045147</td>
# 	</tr>
# 	<tr>
# 		<td>4</td>
# 		<td>4</td>
# 		<td>coupon</td>
# 		<td>2500</td>
# 		<td>2025-09-02 10:15:32.045147</td>
# 	</tr>
# 	<tr>
# 		<td>2</td>
# 		<td>2</td>
# 		<td>credit_card</td>
# 		<td>2000</td>
# 		<td>2025-09-02 10:15:32.045147</td>
# 	</tr>
# 	<tr>
# 		<td>1</td>
# 		<td>1</td>
# 		<td>credit_card</td>
# 		<td>1000</td>
# 		<td>2025-09-02 10:

# %%
tdml.remove_context()
# Out:
# True

# %% [markdown]
# **If you have already opened the other notebooks, be sure to restart their kernels, so they can also use the freshly installed packages**
