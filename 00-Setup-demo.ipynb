# %% [markdown]
# # 1) Install Chatbot Widget

# %%
# %%capture
# # '%%capture' suppresses the display of installation steps of the following packages
# !pip install "git+https://github.com/martinhillebrand/chatbot-widget.git"

# %%
# %%capture
# # '%%capture' suppresses the display of installation steps of the following packages
# !pip install teradataml-plus plotly

# %%
try:
    import chatbot_widget
    print("chatbot_widget installed")
except:
    print("chatbot_widget could not be loaded, please restart the kernel")
# Out:
# chatbot_widget installed

# %% [markdown]
# # 2) Optional: Get the teradata-mcp-server (Community Edition) Code

# %%
# !git clone  https://github.com/Teradata/teradata-mcp-server.git
# Out:
# Cloning into 'teradata-mcp-server'...
# remote: Enumerating objects: 3728, done.
# remote: Counting objects: 100% (636/636), done.
# remote: Compressing objects: 100% (134/134), done.
# remote: Total 3728 (delta 541), reused 506 (delta 502), pack-reused 3092 (from 2)
# Receiving objects: 100% (3728/3728), 80.87 MiB | 40.73 MiB/s, done.
# Resolving deltas: 100% (2225/2225), done.

# %%
# !ls
# Out:
# 00-Setup-demo.ipynb	      example_chat.png	sample_data_jaffleshop
# 01-explore-MCP-Servers.ipynb  old		tdmcpcommunity.py
# 02-chat-with-MCP.ipynb	      README.md		teradata-mcp-server

# %%
import tomllib,shlex

with open("teradata-mcp-server/pyproject.toml", "rb") as f:
    deps = tomllib.load(f)["project"]["dependencies"]
deps_str = " ".join(shlex.quote(d) for d in deps)

print(deps_str)
# Out:
# 'pydantic>=2.8.0,<3.0.0' 'fastmcp>=2.12.0,<3.0.0' 'mcp[cli]>=1.0.0,<2.0.0' 'teradatasqlalchemy>=20.0.0.0' 'python-dotenv>=1.0.0' 'PyYAML>=6.0.0' 'sqlalchemy>=2.0.0,<3.0.0'

# %%
# %%capture
# # '%%capture' suppresses the display of installation steps of the following packages
# !pip install -U {deps_str}

# %% [markdown]
# **FYI: We can start the MCP server later through the wrapper script tdmcpcommunity.py**

# %% [markdown]
# # 3 Load some dummy data to the demo_user database

# %%
# TODO example from mcp demo

# %%
host = 'host.docker.internal'
user = 'demo_user'

# %%
import getpass
db_pw = getpass.getpass("Enter DB Password here")
# Out:
# Enter DB Password here ················

# %%
import tdmlplus
import teradataml as tdml
import os
import pandas as pd

# %%
tdml.create_context(host, user, db_pw)
# Out:
# Engine(teradatasql://demo_user:***@host.docker.internal)

# %%
all_csvs = os.listdir("sample_data_jaffleshop/")
for f in all_csvs:
    if f.endswith(".csv"):
        table_name = f.split(".csv")[0]
        df = pd.read_csv("sample_data_jaffleshop/"+f)
        tdml.copy_to_sql(df, table_name, if_exists="replace")
        print(table_name, " uploaded")
# Out:
# dim_payment_method  uploaded
# customer_lifetime_value  uploaded
# dim_customers  uploaded
# sim_payments  uploaded
# key_customer  uploaded
# raw_customers  uploaded
# stg_payments  uploaded
# stg_orders  uploaded
# sim_customers  uploaded
# sim_orders  uploaded
# fct_orders  uploaded
# lim_payments  uploaded
# lim_orders  uploaded
# lim_customers  uploaded
# stg_customers  uploaded
# customer  uploaded
# order_payments  uploaded
# raw_orders  uploaded
# raw_payments  uploaded

# %%
tdml.widgets.tab_dfs(table_names = [f.split(".csv")[0] for f in all_csvs] )
# Out:
#     <style>
#         .tab-container-be55903b30ab47989175935e12d15873 {
#             border-bottom: 2px solid #ddd;
#             display: flex;
#         }
#         .tab-label-be55903b30ab47989175935e12d15873 {
#             padding: 10px 15px;
#             cursor: pointer;
#             border: 1px solid #ddd;
#             border-bottom: none;
#             background: #f1f1f1;
#             margin-right: 5px;
#         }
#         .tab-label-be55903b30ab47989175935e12d15873.active {
#             background: white;
#             border-top: 2px solid #007bff;
#             font-weight: bold;
#         }
#         .tab-content-be55903b30ab47989175935e12d15873 {
#             display: none;
#             padding: 15px;
#             border: 1px solid #ddd;
#             text-align: left;
#         }
#         .tab-content-be55903b30ab47989175935e12d15873.active {
#             display: block;
#         }
#     </style>
#
#     <div class="tab-container-be55903b30ab47989175935e12d15873">
#     <div class="tab-label-be55903b30ab47989175935e12d15873 active" data-tab="e7c5887d43254ccfa881840f23cb4aba">dim_payment_method</div><div class="tab-label-be55903b30ab47989175935e12d15873 " data-tab="7a5cc5317ace4545986f8e6b814a4f72">customer_lifetime_value</div><div class="tab-label-be55903b30ab47989175935e12d15873 " data-tab="4b79a133d4e54e6e871dccc81fc96415">dim_customers</div><div class="tab-label-be55903b30ab47989175935e12d15873 " data-tab="039b2d4ca52f4f659e5545bc90064bb1">sim_payments</div><div class="tab-label-be55903b30ab47989175935e12d15873 " data-tab="5306ea2bb73945718ab7173f062c8418">key_customer</div><div class="tab-label-be55903b30ab47989175935e12d15873 " data-tab="9ca957e67a2b4229b84914d032bbd6e5">raw_customers</div><div class="tab-label-be55903b30ab47989175935e12d15873 " data-tab="32968914b221468c9d6a54689c7bcecd">stg_payments</div><div class="tab-label-be55903b30ab47989175935e12d15873 " data-tab="97646254c3fe40bda2281ff8ed1181ab">stg_orders</div><div class="tab-label-be55903b30ab47989175935e12d15873 " data-tab="8c152f9936cd40589dfce2d43d441165">sim_customers</div><div class="tab-label-be55903b30ab47989175935e12d15873 " data-tab="b1fa6a0a58474e589bc3313317dcf61f">sim_orders</div><div class="tab-label-be55903b30ab47989175935e12d15873 " data-tab="d43afa004263401e8162d0bd04dea980">fct_orders</div><div class="tab-label-be55903b30ab47989175935e12d15873 " data-tab="c9bb6ae16b90471aa6ba992dd203e53b">lim_payments</div><div class="tab-label-be55903b30ab47989175935e12d15873 " data-tab="e38473cd0e04486081a59f7a57b928be">lim_orders</div><div class="tab-label-be55903b30ab47989175935e12d15873 " data-tab="141048ff02124eafb9579cd6cd5d7057">lim_customers</div><div class="tab-label-be55903b30ab47989175935e12d15873 " data-tab="b39bfef3dfb54d0b9e8f6fe067859df4">stg_customers</div><div class="tab-label-be55903b30ab47989175935e12d15873 " data-tab="ad0a71196cf345eba1bc26fe82e157be">customer</div><div class="tab-label-be55903b30ab47989175935e12d15873 " data-tab="5110367b39f44ca89526567c94c4a687">order_payments</div><div class="tab-label-be55903b30ab47989175935e12d15873 " data-tab="9a1b1b2ede2046149558dc62c79315a3">raw_orders</div><div class="tab-label-be55903b30ab47989175935e12d15873 " data-tab="9edc189c448a4f5c9705ec664fe28fc2">raw_payments</div></div><div class="tab-content-be55903b30ab47989175935e12d15873 active" id="tab-e7c5887d43254ccfa881840f23cb4aba"><style type="text/css">
# 	table { border:ridge 5px}
# 	table td {border:inset 1px;}
# 	table tr#HeaderRow {background-color:grey; color:white;}
# 	</style>
# <html><table style="min-width:1000px;">
# 	<tr id="HeaderRow">
# <th>payment_method</th><th>total_amount</th><th>frequency_count</th>
# </tr>
# 	<tr>
# 		<td>bank_transfer</td>
# 		<td>411</td>
# 		<td>33</td>
# 	</tr>
# 	<tr>
# 		<td>gift_card</td>
# 		<td>205</td>
# 		<td>12</td>
# 	</tr>
# 	<tr>
# 		<td>credit_card</td>
# 		<td>871</td>
# 		<td>55</td>
# 	</tr>
# 	<tr>
# 		<td>coupon</td>
# 		<td>185</td>
# 		<td>13</td>
# 	</tr>
# </table></html></div><div class="tab-content-be55903b30ab47989175935e12d15873 " id="tab-7a5cc5317ace4545986f8e6b814a4f72"><style type="text/css">
# 	table { border:ridge 5px}
# 	table td {border:inset 1px;}
# 	table tr#HeaderRow {background-color:grey; color:white;}
# 	</style>
# <html><table style="min-width:1000px;">
# 	<tr id="HeaderRow">
# <th>customer_key</th><th>total_amount_usd</th><th>valid_period</th>
# </tr>
# 	<tr>
# 		<td>2</td>
# 		<td>15</td>
# 		<td>2018-01-23,9999-12-31</td>
# 	</tr>
# 	<tr>
# 		<td>6</td>
# 		<td>4</td>
# 		<td>2018-03-03,9999-12-31</td>
# 	</tr>
# 	<tr>
# 		<td>15</td>
# 		<td>25</td>
# 		<td>2018-01-05,2018-02-20</td>
# 	</tr>
# 	<tr>
# 		<td>19</td>
# 		<td>28</td>
# 		<td>2018-03-02,2018-03-14</td>
# 	</tr>
# 	<tr>
# 		<td>9</td>
# 		<td>8</td>
# 		<td>2018-02-11,2018-03-08</td>
# 	</tr>
# 	<tr>
# 		<td>15</td>
# 		<td>47</td>
# 		<td>2018-02-20,9999-12-31</td>
# 	</tr>
# 	<tr>
# 		<td>3</td>
# 		<td>39</td>
# 		<td>2018-03-11,9999-12-31</td>
# 	</tr>
# 	<tr>
# 		<td>3</td>
# 		<td>23</td>
# 		<td>2018-01-12,2018-03-11</td>
# 	</tr>
# 	<tr>
# 		<td>8</td>
# 		<td>12</td>
# 		<td>2018-02-02,9999-12-31</td>
# 	</tr>
# 	<tr>
# 		<td>1</td>
# 		<td>1</td>
# 		<td>2018-01-15,9999-12-31</td>
# 	</tr>
# </table></html></div><div class="tab-content-be55903b30ab47989175935e12d15873 " id="tab-4b79a133d4e54e6e871dccc81fc96415"><style type="text/css">
# 	table { border:ridge 5px}
# 	table td {border:inset 1px;}
# 	table tr#HeaderRow {background-color:grey; color:white;}
# 	</style>
# <html><table style="min-width:1000px;">
# 	<tr id="HeaderRow">
# <th>customer_key</th><th>first_order</th><th>most_recent_order</th><th>number_of_orders</th><th>customer_lifetime_value</th>
# </tr>
# 	<tr>
# 		<td>40</td>
# 		<td>None</td>
# 		<td>None</td>
# 		<td>None</td>
# 		<td>None</td>
# 	</tr>
# 	<tr>
# 		<td>38</td>
# 		<td>None</td>
# 		<td>None</td>
# 		<td>None</td>
# 		<td>None</td>
# 	</tr>
# 	<tr>
# 		<td>34</td>
# 		<td>None</td>
# 		<td>None</td>
# 		<td>None</td>
# 		<td>None</td>
# 	</tr>
# 	<tr>
# 		<td>80</td>
# 		<td>2018-01-31</td>
# 		<td>2018-03-05</td>
# 		<td>2.0</td>
# 		<td>26.0</td>
# 	</tr>
# 	<tr>
# 		<td>78</td>
# 		<td>2018-02-08</td>
# 		<td>2018-02-08</td>
# 		<td>1.0</td>
# 		<td>29.0</td>
# 	</tr>
# 	<tr>
# 		<td>13</td>
# 		<td>2018-02-21</td>
# 		<td>2018-04-04</td>
# 		<td>2.0</td>
# 		<td>27.0</td>
# 	</tr>
# 	<tr>
# 		<td>59</td>
# 		<td>None</td>
# 		<td>None</td>
# 		<td>None</td>
# 		<td>None</td>
# 	</tr>
# 	<tr>
# 		<td>19</td>
# 		<td>2018-03-02</td>
# 		<td>2018-03-14</td>
# 		<td>2.0</td>
# 		<td>57.0</td>
# 	</tr>
# 	<tr>
# 		<td>17</td>
# 		<td>None</td>
# 		<td>None</td>
# 		<td>None</td>
# 		<td>None</td>
# 	</tr>
# 	<tr>
# 		<td>61</td>
# 		<td>2018-03-23</td>
# 		<td>2018-03-23</td>
# 		<td>1.0</td>
# 		<td>27.0</td>
# 	</tr>
# </table></html></div><div class="tab-content-be55903b30ab47989175935e12d15873 " id="tab-039b2d4ca52f4f659e5545bc90064bb1"><style type="text/css">
# 	table { border:ridge 5px}
# 	table td {border:inset 1px;}
# 	table tr#HeaderRow {background-color:grey; color:white;}
# 	</style>
# <html><table style="min-width:1000px;">
# 	<tr id="HeaderRow">
# <th>id</th><th>order_id</th><th>payment_method</th><th>amount</th><th>last_update_ts</th>
# </tr>
# 	<tr>
# 		<td>3</td>
# 		<td>3</td>
# 		<td>coupon</td>
# 		<td>100</td>
# 		<td>2025-09-02 10:15:32.045147</td>
# 	</tr>
# 	<tr>
# 		<td>5</td>
# 		<td>5</td>
# 		<td>bank_transfer</td>
# 		<td>1700</td>
# 		<td>2025-09-02 10:15:32.045147</td>
# 	</tr>
# 	<tr>
# 		<td>6</td>
# 		<td>6</td>
# 		<td>credit_card</td>
# 		<td>600</td>
# 		<td>2025-09-02 10:15:32.045147</td>
# 	</tr>
# 	<tr>
# 		<td>7</td>
# 		<td>7</td>
# 		<td>credit_card</td>
# 		<td>1600</td>
# 		<td>2025-09-02 10:15:32.045147</td>
# 	</tr>
# 	<tr>
# 		<td>9</td>
# 		<td>9</td>
# 		<td>gift_card</td>
# 		<td>2300</td>
# 		<td>2025-09-02 10:15:32.045147</td>
# 	</tr>
# 	<tr>
# 		<td>10</td>
# 		<td>9</td>
# 		<td>bank_transfer</td>
# 		<td>0</td>
# 		<td>2025-09-02 10:15:32.045147</td>
# 	</tr>
# 	<tr>
# 		<td>8</td>
# 		<td>8</td>
# 		<td>credit_card</td>
# 		<td>2300</td>
# 		<td>2025-09-02 10:15:32.045147</td>
# 	</tr>
# 	<tr>
# 		<td>4</td>
# 		<td>4</td>
# 		<td>coupon</td>
# 		<td>2500</td>
# 		<td>2025-09-02 10:15:32.045147</td>
# 	</tr>
# 	<tr>
# 		<td>2</td>
# 		<td>2</td>
# 		<td>credit_card</td>
# 		<td>2000</td>
# 		<td>2025-09-02 10:15:32.045147</td>
# 	</tr>
# 	<tr>
# 		<td>1</td>
# 		<td>1</td>
# 		<td>credit_card</td>
# 		<td>1000</td>
# 		<td>2025-09-02 10:

# %%
tdml.remove_context()
# Out:
# True

# %% [markdown]
# **If you have already opened the other notebooks, be sure to restart their kernels, so they can also use the freshly installed packages**
